# %%
import os
from pydub import AudioSegment # Ensure pydub is imported or available

# %%
#!pip install -U nemo_toolkit['asr']

# %%
import nemo.collections.asr as nemo_asr
asr_model = nemo_asr.models.ASRModel.from_pretrained(model_name="nvidia/parakeet-tdt-0.6b-v3")
# Out:
# [NeMo W 2026-03-27 08:33:05 megatron_init:62] Megatron num_microbatches_calculator not found, using Apex version.
# WARNING:nv_one_logger.api.config:OneLogger: Setting error_handling_strategy to DISABLE_QUIETLY_AND_REPORT_METRIC_ERROR for rank (rank=0) with OneLogger disabled. To override: explicitly set error_handling_strategy parameter.
# WARNING:nv_one_logger.training_telemetry.api.training_telemetry_provider:No exporters were provided. This means that no telemetry data will be collected.
# [NeMo W 2026-03-27 08:33:07 nemo_logging:364] /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#       m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
#
# [NeMo W 2026-03-27 08:33:07 nemo_logging:364] /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#       m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
#
# ...

# %%
def convert_m4a_to_wav(m4a_file_path, wav_file_path):
    """
    Converts an M4A audio file to a WAV audio file.

    Args:
        m4a_file_path (str): The path to the input M4A file.
        wav_file_path (str): The path to the output WAV file.
    """
    try:
        audio = AudioSegment.from_file(m4a_file_path, format="m4a")

        # Convert to mono if it's stereo
        if audio.channels > 1:
            audio = audio.set_channels(1)

        audio.export(wav_file_path, format="wav")
        print(f"Successfully converted '{m4a_file_path}' to '{wav_file_path}'")
    except Exception as e:
        print(f"Error converting file: {e}")

# %%
# Example usage (you'll need to replace 'your_audio.m4a' with your actual file path)
convert_m4a_to_wav('test.m4a', 'test.wav')
# Out:
# Successfully converted 'test.m4a' to 'test.wav'

# %%
# Transcribe the mono audio file
output = asr_model.transcribe(['test.wav'])
print(output[0].text)
# Out:
# [NeMo W 2026-03-27 08:40:43 dataloader:826] The following configuration keys are ignored by Lhotse dataloader: use_start_end_token
# [NeMo W 2026-03-27 08:40:43 dataloader:523] You are using a non-tarred dataset and requested tokenization during data sampling (pretokenize=True). This will cause the tokenization to happen in the main (GPU) process,possibly impacting the training speed if your tokenizer is very large.If the impact is noticable, set pretokenize=False in dataloader config.(note: that will disable token-per-second filtering and 2D bucketing features)
# Transcribing: 1it [00:10, 10.75s/it]
# Dalis grožio salonuose apsilankiusių lietuvių kelia klausimą: koliau negalima susikalbėti lietuvių kalba ir ar gali būti, kad dėl to paslaugos kainoja pigiau. Kirpėjų ir Gružio specialistų asociacijos prezidentė sakė pastebenti, jo kartais užsieniečiai dempinguoja kaines ir tikina, kad sektorius šiuo metu nenva.
